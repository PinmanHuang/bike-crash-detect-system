# %% [markdown]
# ## Classification ##
# **problem**: Chapter 6 of the textbook.
#
# Implement the neural network for binary classification by using the Ionosphere dataset. There are **34 different features and 2 classes**. The last column represents their corresponding labels:“g” for good and “b” for bad.
#
# ## Imports ##

# %%
import pandas as pd
import itertools
import numpy as np
import matplotlib.pyplot as plt
import math
import random

# %% [markdown]
# ## Load data
# The training data is 80% data points of the dataset ionosphere_data.csv, and the test data is 20% data points of the dataset ionosphere_data.csv.

# %%
# Load the data into python and take a look
dataset = pd.read_csv(r'train.csv')
dataset.head()
# Out:
#           92         50          3          4          5          6  \
# 0  14.414500  10.333799   9.352743  10.142613  12.120417  12.355023
# 1   9.433859   8.568956  12.123720  10.644106  10.696129   7.550219
# 2  11.107749  12.668520   7.492116   9.437659   4.178433   5.288714
# 3   9.999320  10.353328  11.395811  15.231526  13.234361   5.457215
# 4  11.027842  19.675092  13.154725  15.024992  10.071172  13.575985
#
#            7          8          9         10  ...           42         43  \
# 0  10.900592   8.660404  10.586170   8.763641  ...    22.786165  17.959691
# 1   9.078953  10.057290   9.717767  10.030454  ...     6.182791   3.449217
# 2   7.715614   6.531937   5.600375   9.086919  ...     9.412152   9.749779
# 3   9.127574   9.443119   7.775326   9.677091  ...    10.887819   8.290724
# 4  10.587630   6.202523  14.762171   9.777172  ...     9.446343   9.763959
#
#           44         45         46         47         48         49  \
# 0  10.794632   7.214021   9.791618  14.205858  10.752097   9.917792
# 1  10.826144  10.694558  11.334306   9.931354   8.414683  10.052965
# 2  11.887371  12.121522  11.102166  11.054379   9.855425  10.414980
# 3  10.287186   9.993162  10.450866  10.845141   9.056059   9.217662
# 4   8.687474  10.846700   8.020605   9.343222   9.885043   9.596010
#
#         50.1  label
# 0   6.760629      0
# 1   9.152404      0
# 2  11.483610      0
# 3   9.548136      0
# 4  11.941516      0
#
# [5 rows x 51 columns]

# %%
# Load the data into python and take a look
testset = pd.read_csv(r'test2.csv')
testset.head()
# Out:
#           41         50          3          4          5          6  \
# 0  10.441810   8.593439   9.665200   7.837742   8.418854  10.633221
# 1  10.488307  14.020057   9.543824  10.942139   9.981478  11.238132
# 2  10.022644   9.217532  13.003365   8.143758  11.034464   9.943686
# 3  10.275646  11.448646   9.843337  12.539996   9.542788   8.209567
# 4   8.103320   7.509793   8.637129   8.557973   9.355538   9.652823
#
#            7          8          9         10  ...           42         43  \
# 0  11.616312   9.726489   9.068500  10.076959  ...    11.137549  10.743263
# 1   9.403196  14.062301   9.988517   8.823043  ...     5.371164  10.629453
# 2  13.542658  11.520286   9.924732  10.575570  ...     4.530850  12.197619
# 3  11.332167   8.341211  14.885811   9.216127  ...    24.222933  10.596792
# 4   9.407560  10.357905   9.875713  12.639627  ...     9.886809  22.851551
#
#           44         45         46         47         48         49  \
# 0   8.234324  11.423511  10.646431   9.180920  10.454573   6.823518
# 1   8.232448  10.115246  11.840404  11.772774  12.062587  13.767371
# 2  12.809957  12.784635   9.307529  11.531843   6.636219  12.400713
# 3   7.957707   8.797801  10.282309  14.025680   8.711401   9.633094
# 4  13.510030  12.541187  20.504597  13.774945   9.750051   9.503783
#
#         50.1  label
# 0   9.222885      0
# 1  11.566542      0
# 2  11.843665      0
# 3   7.109613      0
# 4  13.290922      0
#
# [5 rows x 51 columns]

# %%
# Get more informations about dataset
dataset.describe()
# Out:
#               92         50          3          4          5          6  \
# count  92.000000  92.000000  92.000000  92.000000  92.000000  92.000000
# mean   10.081099  10.270715  10.007219  10.294485  10.148812  10.038770
# std     1.144481   1.594024   1.330934   1.536122   1.824688   1.573813
# min     7.461402   6.394005   6.494105   6.312353   4.178433   5.288714
# 25%     9.421300   9.327744   9.290964   9.629602   9.319278   9.409871
# 50%    10.019438  10.074856  10.023895  10.122503  10.023509  10.065043
# 75%    10.666738  10.684117  10.679439  10.756697  10.722044  11.002742
# max    14.414500  19.675092  15.601272  15.231526  18.034730  14.828487
#
#                7          8          9         10    ...             42  \
# count  92.000000  92.000000  92.000000  92.000000    ...      92.000000
# mean   10.252569  10.406081  10.324347  10.420787    ...      12.340261
# std     1.656483   1.839775   1.634381   1.553899    ...      10.811979
# min     4.718557   6.034456   5.600375   6.627601    ...       3.340804
# 25%     9.464999   9.540778   9.504859   9.663465    ...       9.445892
# 50%    10.139526  10.271011  10.290625  10.196039    ...      10.164846
# 75%    10.806490  11.027956  11.095974  11.114568    ...      11.160333
# max    15.816791  17.222976  15.396872  16.994880    ...      98.019901
#
#               43         44         45         46         47         48  \
# count  92.000000  92.000000  92.000000  92.000000  92.000000  92.000000
# mean   10.519580  10.952400  11.684112  10.728972  10.240890   9.875326
# std     3.823432   6.198817   7.340695   5.088700   2.087124   1.313872
# min     1.689014   1.468219   5.826864   7.077797   5.725948   3.778404
# 25%     9.222544   9.428317   9.674787   9.474779   9.706674   9.555148
# 50%    10.081475  10.095671  10.127531  10.003094  10.044890  10.007423
# 75%    10.914791  10.703305  10.785510  10.408671  10.367617  10.334665
# max    32.574693  59.988181  60.086704  55.519494  28.086697  14.046385
#
#               49       50.1      label
# count  92.000000  92.000000  92.000000
# mean   10.540703  10.203837   0.326087
# std     2.517422   2.013194   0.471348
# min     8.360365   6.760629   0.000000
# 25%     9.708368   9.665298   0.000000
# 50%    10.081147  10.006768   0.000000
# 75%    10.395818  10.277178   1.000000
# max    27.304609  26.720272   1.000000
#
# [8 rows x 51 columns]

# %%
# Get more informations about dataset
testset.describe()
# Out:
#               41         50          3          4          5          6  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean   10.109021  10.179970   9.992409  10.160620  10.289997  10.186471
# std     1.293232   1.647977   1.530224   1.391373   1.472555   2.042845
# min     7.216370   7.509793   7.095252   7.401851   7.186195   7.341519
# 25%     9.420329   9.144113   9.010100   9.511157   9.371606   8.956595
# 50%    10.013296   9.856795   9.810473  10.192958  10.156814   9.658198
# 75%    10.672844  10.522101  10.719141  11.066309  11.034464  11.174229
# max    13.794295  14.205640  14.927993  13.134827  14.383018  15.955139
#
#                7          8          9         10    ...             42  \
# count  41.000000  41.000000  41.000000  41.000000    ...      41.000000
# mean   10.092073  10.353104  10.026594  10.008152    ...      12.965616
# std     1.407792   1.373869   1.569098   1.558113    ...       8.246792
# min     7.871220   7.352102   5.923993   6.892271    ...       4.530850
# 25%     9.108968   9.527072   9.201571   8.823043    ...       9.886809
# 50%     9.798245  10.357905   9.949241   9.666359    ...      10.120543
# 75%    11.024183  11.133490  10.944958  11.203150    ...      11.777546
# max    13.542658  14.062301  14.885811  13.191232    ...      49.343835
#
#               43         44         45         46         47         48  \
# count  41.000000  41.000000  41.000000  41.000000  41.000000  41.000000
# mean   10.372181  10.142655  11.848899  10.261283  10.248168   9.988072
# std     2.384448   1.584564   7.985839   1.872942   1.122481   0.956248
# min     6.277077   5.523848   7.867306   6.165412   8.038930   6.636219
# 25%     9.830127   9.592633   9.787308   9.785775   9.827838   9.792431
# 50%    10.032277  10.020504   9.995924   9.962428   9.987562  10.031694
# 75%    10.596792  10.515688  10.142983  10.282309  10.407137  10.311319
# max    22.851551  14.623197  57.367706  20.504597  14.025680  13.084686
#
#               49       50.1      label
# count  41.000000  41.000000  41.000000
# mean   10.039338  10.161457   0.390244
# std     0.953130   1.089362   0.493865
# min     6.823518   7.109613   0.000000
# 25%     9.763083   9.803158   0.000000
# 50%     9.949925   9.952854   0.000000
# 75%    10.110668  10.300010   1.000000
# max    13.767371  13.290922   1.000000
#
# [8 rows x 51 columns]

# %%
X = dataset.iloc[:,:50].values
y = dataset.iloc[:,50:51].values
Xt = testset

# %% [markdown]
# ## Label Encode ##
# * label "g"
#     * mapping to 1
# * lable "b"
#     * mapping to 0

# %%
# switch case for Orientation and Glazing Area Distribution encode
def label_encode(lab):
    numbers = {
            'g' : 1,
            'b' : 0
        }
    return numbers.get(lab, None)

# %%
tmp = []
for i in y:
    # encode
    i = i.tolist()
    i = label_encode(i[0])
    tmp.append(i)
y = np.array(tmp)

# %% [markdown]
# ## Split Dataset ##
# There are e 34 different features and 2 classes in this dataset. Shuffle the dataset then use 80% of data samples for training and 20% for testing.

# %%
# Splitting the dataset into training and testing set 75-25
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

X_train_seq, X_test_seq = X[:280,:], X[280:350,:]
y_train_seq, y_test_seq = y[:280], y[280:350]

# %%
dataset = []
for i, j in zip(X_train.tolist(), y_train.tolist()):
    dataset.append((i, [j]))

    dataset_seq = []
for i, j in zip(X_train_seq.tolist(), y_train_seq.tolist()):
    dataset_seq.append((i, [j]))

# %% [markdown]
# ## Neural Network ##

# %%
class NeuralNetwork(object):

    def __init__(self, learning_rate=0.5, debug=False):
        """
        Train NeuralNetwork by fixed learning rate
        """
        self.neuron_layers = []
        self.learning_rate = learning_rate
        self.debug = debug

    def train(self, dataset):
        for inputs, outputs in dataset:
            self.feed_forward(inputs)
            self.feed_backword(outputs)
            self.update_weights(self.learning_rate)

    def feed_forward(self, inputs):
        s = inputs
        for (i, l) in enumerate(self.neuron_layers):
            s = l.feed_forward(s)
            '''
            Compare the results of choosing different numbers of nodes in the layer before the output layer 
            '''
            global literation
            global distribution_data
            global EPOCH
            if (i==DISTRIBUTION_DEPTH):
                if (literation>=EPOCH_10*280 and literation<(EPOCH_10+1)*280):
                    distribution_data_10.append(s)
                elif (literation>=EPOCH_390*280 and literation<(EPOCH_390+1)*280):
                    distribution_data_390.append(s)
                literation += 1
            '''
            if (i==OUTPUT_DEPTH and (literation-1)>=EPOCH_10*280 and (literation-1)<(EPOCH_10+1)*280):
                distribution_result_10.append(s)
            if (i==OUTPUT_DEPTH and (literation-1)>=EPOCH_390*280 and (literation-1)<(EPOCH_390+1)*280):
                distribution_result_390.append(s)
            '''
            '''
            Debug Mode
            '''
            if self.debug:
                print ("Layer %s:" % (i+1), " output:%s" % s)
        return s

    def feed_backword(self, outputs):
        layer_num = len(self.neuron_layers)
        l = layer_num
        previous_deltas = [] 
        while l != 0:
            current_layer = self.neuron_layers[l - 1]
            if len(previous_deltas) == 0:
                for i in range(len(current_layer.neurons)):
                    error = -(outputs[i] - current_layer.neurons[i].output)
                    current_layer.neurons[i].calculate_delta(error)
            else:
                previous_layer = self.neuron_layers[l]
                for i in range(len(current_layer.neurons)):
                    error = 0
                    for j in range(len(previous_deltas)):
                        error += previous_deltas[j] * previous_layer.neurons[j].weights[i]
                    current_layer.neurons[i].calculate_delta(error)
            previous_deltas = current_layer.get_deltas()
            if self.debug:
                print ("Layer %s:" % l, "deltas:%s" % previous_deltas)
            l -= 1

    def update_weights(self, learning_rate):
        for l in self.neuron_layers:
            l.update_weights(learning_rate)

    def calculate_total_error(self, dataset):
        """
        Return mean squared error of dataset
        """
        total_error = 0
        for inputs, outputs in dataset:
            actual_outputs = self.feed_forward(inputs)
            for i in range(len(outputs)):
                total_error += -(outputs[i] * np.log(actual_outputs[i]))
        return total_error
        
    def get_output(self, inputs):
        return self.feed_forward(inputs)

    def add_layer(self, neruon_layer):
        self.neuron_layers.append(neruon_layer)

    def dump(self):
        for (i, l) in enumerate(self.neuron_layers):
            print ("Dump layer: %s" % (i+1))
            l.dump()

# %%
class NeuronLayer(object):

    def __init__(self, input_num, neuron_num, init_weights=[], bias=1):
        self.neurons = []
        weight_index = 0
        for i in range(neuron_num):
            n = Neuron(input_num)
            for j in range(input_num):
                if weight_index < len(init_weights):
                    n.weights[j] = init_weights[weight_index]
                    weight_index += 1
            n.bias = bias
            self.neurons.append(n)

    def feed_forward(self, inputs):
        outputs = []
        for n in self.neurons:
            outputs.append(n.calculate_output(inputs))
        return outputs

    def get_deltas(self):
        return [n.delta for n in self.neurons]

    def update_weights(self, learning_rate):
        for n in self.neurons:
            n.update_weights(learning_rate)

    def dump(self):
        for (i, n) in enumerate(self.neurons):
            print ("\t-Dump neuron: %s" % (i+1))
            n.dump()

# %%
class Neuron(object):

    def __init__(self, weight_num):
        self.weights = []
        self.bias = 0
        self.output = 0
        self.delta = 0
        self.inputs = []
        for i in range(weight_num):
            random.seed(i)
            self.weights.append(random.random())

    def calculate_output(self, inputs):
        self.inputs = inputs
        if len(inputs) != len(self.weights):
            raise Exception("Input number not fit weight number")
        self.output = 0
        for (i, w) in enumerate(self.weights):
            self.output += w * inputs[i]
        self.output = self.activation_function(self.output + self.bias)
        return self.output

    def activation_function(self, x):
        """Using sigmoid function"""
        return 1 / (1 + math.exp(-x))

    def calculate_delta(self, error):
        """ Using g' of sigmoid """
        self.delta = error * self.output * (1 - self.output)

    def update_weights(self, learning_rate):
        for (i, w) in enumerate(self.weights):
            new_w = w - learning_rate * self.delta * self.inputs[i]
            self.weights[i] = new_w
        self.bias = self.bias - learning_rate * self.delta

    def dump(self):
        print ("\t\t-- weights:", self.weights)
        print ("\t\t-- bias:", self.bias)

# %% [markdown]
# ## Train ##

# %%
def error_rate(data, label):
    error_num = 0
    for x, t in zip(data, label):
        y = nn.get_output(x)[0]
        if (y>=0.5):
            y = 1
        else:
            y = 0
        if (y!=t):
            error_num += 1
    return error_num/len(label)

# %%
literation = 0

DISTRIBUTION_DEPTH = 2
OUTPUT_DEPTH = 3

EPOCH_10 = 20
distribution_data_10 = []
distribution_result_10 = []

EPOCH_390 = 70
distribution_data_390 = []
distribution_result_390 = []

# %%
nn = NeuralNetwork()
nn.debug = False

# %%
hidden_layer_1 = NeuronLayer(input_num=34, neuron_num=10, bias=0.5)
hidden_layer_2 = NeuronLayer(input_num=10, neuron_num=5, bias=0.5)
hidden_layer_3 = NeuronLayer(input_num=5, neuron_num=2, bias=0.5)
output_layer = NeuronLayer(input_num=2, neuron_num=1, bias=0.5)
nn.add_layer(hidden_layer_1)
nn.add_layer(hidden_layer_2)
nn.add_layer(hidden_layer_3)
nn.add_layer(output_layer)
# nn.dump()

tracking = []
training_error_rate = []
test_error_rate = []
for i in range(1000):
    nn.train(dataset)
    tracking.append(nn.calculate_total_error(dataset))
    
    training_error_rate.append(error_rate(X_train, y_train))
    test_error_rate.append(error_rate(X_test, y_test))
    
    
    if (i==EPOCH_10):
        for x in X_train:
            distribution_result_10.append(nn.get_output(x)[0])
    if (i==EPOCH_390):
        for x in X_train:
            distribution_result_390.append(nn.get_output(x)[0])

# %% [markdown]
# ## Predict ##

# %%
predit_train = []
predit_test = []
for x in X_train_seq.tolist():
    predit_train.append(nn.get_output(x))
for x in X_test_seq.tolist():
    predit_test.append(nn.get_output(x))

# %%
predit_testing = []
for x in X_test.tolist():
    predit_testing.append(nn.get_output(x))

# %% [markdown]
# ## Distribution of latent features ##

# %%
good_distribution_10 = []
bad_distribution_10 = []
for data, result in zip(distribution_data_10, distribution_result_10):
    if (result[0]<=0.5):
        bad_distribution_10.append(data)
    else:
        good_distribution_10.append(data)

good_distribution_390 = []
bad_distribution_390 = []
for data, result in zip(distribution_data_390, distribution_result_390):
    if (result[0]<=0.5):
        bad_distribution_390.append(data)
    else:
        good_distribution_390.append(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-c570cc6ed8bc> in <module>()
#       2 bad_distribution_10 = []
#       3 for data, result in zip(distribution_data_10, distribution_result_10):
# ----> 4     if (result[0]<=0.5):
#       5         bad_distribution_10.append(data)
#       6     else:
#
# TypeError: 'float' object is not subscriptable

# %%
# %matplotlib notebook 
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
fig.suptitle('3D', fontsize=16)
ax = fig.gca(projection='3d')
ax.scatter(*zip(*good_distribution_10), c='b')
ax.scatter(*zip(*bad_distribution_10), c='r')
ax.view_init(elev=10, azim=10)
plt.savefig('2_3D_Feature_10')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
fig = plt.figure()
fig.suptitle('3D', fontsize=16)
ax = fig.gca(projection='3d')
ax.scatter(*zip(*good_distribution_390), c='b')
ax.scatter(*zip(*bad_distribution_390), c='r')
ax.view_init(elev=10, azim=10)
plt.savefig('2_3D_Feature_390')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
plt.scatter(*zip(*good_distribution_10), c='b')
plt.scatter(*zip(*bad_distribution_10), c='r')
plt.savefig('2_2D_Feature_10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-aafc1a115535> in <module>()
#       1 get_ipython().magic('matplotlib inline')
# ----> 2 plt.scatter(*zip(*good_distribution_10), c='b')
#       3 plt.scatter(*zip(*bad_distribution_10), c='r')
#       4 plt.savefig('2_2D_Feature_10')
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
plt.scatter(*zip(*good_distribution_390), c='b')
plt.scatter(*zip(*bad_distribution_390), c='r')
plt.savefig('2_2D_Feature_390')

# %% [markdown]
# ## Error ##

# %%
square_error = []
for (i, e) in enumerate(tracking):
    square_error.append((e/len(dataset))**0.5)

# %%
# %matplotlib inline
plt.suptitle('Training Curve', fontsize=16)
plt.plot(range(1000), square_error, 'b-')
plt.xlabel('Epoch')

plt.savefig('2_Training_Curve')

# %%
plt.suptitle('Training Error Rate', fontsize=16)
plt.plot(range(1000), training_error_rate, 'b-')
plt.xlabel('Epoch')

plt.savefig('2_Training_Error_Rate')

# %%
plt.suptitle('Test Error Rate', fontsize=16)
plt.plot(range(1000), test_error_rate, 'b-')
plt.xlabel('Epoch')

plt.savefig('2_Test_Error_Rate')

# %%
training_error_rate_partial = training_error_rate[0:200]
test_error_rate_partial = test_error_rate[0:200]

# %%
plt.suptitle('Error Rate', fontsize=16)
plt.plot(range(200), training_error_rate_partial, 'b-')
plt.plot(range(200), test_error_rate_partial, 'r-')
plt.xlabel('Epoch')
# Out:
# Text(0.5,0,'Epoch')
